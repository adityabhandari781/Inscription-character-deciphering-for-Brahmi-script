# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader
# import numpy as np

# # --- Configuration ---
# CONTEXT_SIZE = 5  # 5 chars before, 5 chars after
# WINDOW_SIZE = (CONTEXT_SIZE * 2) + 1  # Total input length = 11
# BATCH_SIZE = 32
# EMBED_DIM = 64
# N_HEADS = 4
# N_LAYERS = 2
# LR = 0.001
# EPOCHS = 50

# # --- 1. Data Preparation ---
# class CharTokenizer:
#     def __init__(self, text):
#         # Create a set of unique characters + special tokens
#         chars = sorted(list(set(text)))
#         self.char2idx = {c: i+2 for i, c in enumerate(chars)}
        
#         # Reserve 0 for Padding, 1 for Mask
#         self.char2idx['<pad>'] = 0
#         self.char2idx['<mask>'] = 1
        
#         self.idx2char = {i: c for c, i in self.char2idx.items()}
#         self.vocab_size = len(self.char2idx)
#         self.mask_token_id = self.char2idx['<mask>']
#         self.pad_token_id = self.char2idx['<pad>']

#     def encode(self, s):
#         return [self.char2idx.get(c, 0) for c in s]

#     def decode(self, indices):
#         return "".join([self.idx2char.get(idx, '') for idx in indices])

# class MaskedCharDataset(Dataset):
#     def __init__(self, text, tokenizer):
#         self.tokenizer = tokenizer
#         self.data = []
        
#         # Create sliding windows over the text
#         # We iterate through the text and pick 'i' as the target to be masked
#         encoded_text = tokenizer.encode(text)
        
#         for i in range(len(encoded_text)):
#             # Define window boundaries
#             start = i - CONTEXT_SIZE
#             end = i + CONTEXT_SIZE + 1
            
#             # Extract window with padding if near edges
#             src_window = []
            
#             # Padding for left side
#             if start < 0:
#                 src_window.extend([tokenizer.pad_token_id] * abs(start))
#                 src_window.extend(encoded_text[0:i])
#             else:
#                 src_window.extend(encoded_text[start:i])
                
#             # The Mask itself
#             src_window.append(tokenizer.mask_token_id)
            
#             # Padding for right side
#             if end > len(encoded_text):
#                 src_window.extend(encoded_text[i+1:])
#                 src_window.extend([tokenizer.pad_token_id] * (end - len(encoded_text)))
#             else:
#                 src_window.extend(encoded_text[i+1:end])
                
#             target_char = encoded_text[i]
            
#             self.data.append((torch.tensor(src_window), torch.tensor(target_char)))

#     def __len__(self):
#         return len(self.data)

#     def __getitem__(self, idx):
#         return self.data[idx]

# # --- 2. Model Architecture (Transformer Encoder) ---
# class CharTransformer(nn.Module):
#     def __init__(self, vocab_size, embed_dim, n_heads, n_layers):
#         super(CharTransformer, self).__init__()
        
#         self.embedding = nn.Embedding(vocab_size, embed_dim)
#         self.pos_encoder = nn.Parameter(torch.randn(1, WINDOW_SIZE, embed_dim))
        
#         encoder_layers = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=n_heads, batch_first=True)
#         self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers=n_layers)
        
#         self.fc_out = nn.Linear(embed_dim, vocab_size)

#     def forward(self, x):
#         # x shape: [batch_size, window_size]
        
#         # 1. Embed and add position info
#         x = self.embedding(x) + self.pos_encoder
        
#         # 2. Pass through Transformer
#         # We don't need a mask here because the Transformer Encoder looks at everything
#         x = self.transformer_encoder(x)
        
#         # 3. We only care about the prediction at the MASK position
#         # The mask is always at the center index: CONTEXT_SIZE (e.g., index 5)
#         mask_pos_output = x[:, CONTEXT_SIZE, :]
        
#         output = self.fc_out(mask_pos_output)
#         return output

# # --- 3. Training & Inference ---

# # Dummy Data (Brahmi text simulation or English for testing)
# # You should load your JSON text here.
# raw_text = "hello world this is a test string for the transformer model to predict missing chars" * 10

# # Initialize
# tokenizer = CharTokenizer(raw_text)
# dataset = MaskedCharDataset(raw_text, tokenizer)
# dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# model = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS)
# optimizer = optim.Adam(model.parameters(), lr=LR)
# criterion = nn.CrossEntropyLoss()

# # Training Loop
# print("Starting training...")
# model.train()
# for epoch in range(EPOCHS):
#     total_loss = 0
#     for src, tgt in dataloader:
#         optimizer.zero_grad()
#         output = model(src)
#         loss = criterion(output, tgt)
#         loss.backward()
#         optimizer.step()
#         total_loss += loss.item()
    
#     if (epoch+1) % 10 == 0:
#         print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataloader):.4f}")

# # Inference Function
# def predict_missing(text_segment, model, tokenizer):
#     model.eval()
#     # Ensure segment is exactly 11 chars with '_' in middle
#     # For flexibility, we just find the '_' and take 5 chars around it
#     if '_' not in text_segment:
#         return "No mask found"
    
#     mask_idx = text_segment.find('_')
    
#     # Pad input manually if needed (simplified for demo)
#     # Ideally, reuse the logic from Dataset class
#     left_context = text_segment[max(0, mask_idx-5):mask_idx]
#     right_context = text_segment[mask_idx+1:mask_idx+6]
    
#     # Pad with <pad> if contexts are short
#     left_ids = [tokenizer.pad_token_id] * (5 - len(left_context)) + tokenizer.encode(left_context)
#     right_ids = tokenizer.encode(right_context) + [tokenizer.pad_token_id] * (5 - len(right_context))
    
#     input_ids = left_ids + [tokenizer.mask_token_id] + right_ids
#     input_tensor = torch.tensor([input_ids])
    
#     with torch.no_grad():
#         output = model(input_tensor)
#         predicted_idx = torch.argmax(output, dim=1).item()
        
#     return tokenizer.decode([predicted_idx])

# # --- Test ---
# test_str = "hello w_rld" # 'o' is missing
# print(f"\nInput: {test_str}")
# prediction = predict_missing(test_str, model, tokenizer)
# print(f"Predicted: {prediction}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import regex as re
import random

# ==========================================
# 1. CONFIGURATION
# ==========================================
FILENAME = r'data/strings.txt'  # REPLACE with your actual file name
CONTEXT_SIZE = 5              # 5 chars before, 5 chars after (used for single mask reference)
WINDOW_SIZE = (CONTEXT_SIZE * 2) + 1
BATCH_SIZE = 32
EMBED_DIM = 64
N_HEADS = 4
N_LAYERS = 2
EPOCHS = 20
LR = 0.001
NUM_MASKS_RANGE = (1, 4)  # Predict 1-4 missing characters
MODEL_PATH = r"models/new_brahmi_model5.pth" # 4: 5% acc

# %%
# ==========================================
# 2. DATA PREPARATION (Tokenizer & Dataset)
# ==========================================
class BrahmiTokenizer:
    def __init__(self, file_path):
        self.pad_token = '<pad>'
        self.mask_token = '<mask>'
        self.unk_token = '<unk>'
        
        # Read file to find all unique graphemes
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
        graphemes = re.findall(r'\X', text)
        unique_chars = sorted(list(set(graphemes)))
        
        # Build maps
        self.char2idx = {self.pad_token: 0, self.mask_token: 1, self.unk_token: 2}
        for i, char in enumerate(unique_chars):
            self.char2idx[char] = i + 3
        self.idx2char = {i: c for c, i in self.char2idx.items()}
        self.vocab_size = len(self.char2idx)
        self.pad_token_id = self.char2idx[self.pad_token]
        self.mask_token_id = self.char2idx[self.mask_token]
        self.unk_token_id = self.char2idx[self.unk_token]

    def get_graphemes(self, text):
        return re.findall(r'\X', text)

    def encode(self, text_list):
        encoded = []
        for g in text_list:
            if g == '_':
                encoded.append(self.mask_token_id)
            else:
                encoded.append(self.char2idx.get(g, self.unk_token_id))
        return encoded

    def decode(self, indices):
        return "".join([self.idx2char.get(idx, '') for idx in indices])

class BrahmiMaskedDataset(Dataset):
    def __init__(self, file_path, tokenizer, num_masks_range=NUM_MASKS_RANGE):
        self.tokenizer = tokenizer
        self.num_masks_range = num_masks_range
        self.data = []
        
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            
        for line in lines:
            line = line.strip()
            if not line: 
                continue
            
            graphemes = tokenizer.get_graphemes(line)
            encoded = tokenizer.encode(graphemes)
            
            # Skip if sequence is too short
            if len(encoded) < 2:
                continue
            
            # Create multiple samples from this line with different mask patterns
            for _ in range(max(5, len(encoded))):  # Create multiple mask patterns per line
                # Use 15% masking rate (BERT-style), minimum 1, maximum 4
                num_masks = max(1, min(4, int(len(encoded) * 0.15)))
                # Add randomness: sometimes do 1-4 randomly, sometimes do 15%
                if random.random() < 0.5:
                    num_masks = random.randint(1, min(4, max(1, len(encoded) - 1)))
                
                num_masks = min(num_masks, max(1, len(encoded) - 1))  # always leave 1 real token
                mask_positions = sorted(random.sample(range(len(encoded)), num_masks))

                input_seq = encoded.copy()
                target_ids = []
                for pos in mask_positions:
                    target_ids.append(encoded[pos])
                    input_seq[pos] = tokenizer.mask_token_id

                self.data.append({
                    'input': torch.tensor(input_seq, dtype=torch.long),
                    'mask_positions': torch.tensor(mask_positions, dtype=torch.long),
                    'target_ids': torch.tensor(target_ids, dtype=torch.long)
                })

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        return item['input'], item['mask_positions'], item['target_ids']

# %%
import torch.nn as nn
# ==========================================
# 3. THE MODEL (Transformer)
# ==========================================
class CharTransformer(nn.Module):
    def __init__(self, vocab_size, embed_dim, n_heads, n_layers, pad_token_id=0, dropout=0.1):
        super(CharTransformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_token_id)
        # Learnable position markers (will handle variable lengths with padding)
        self.pos_encoder = nn.Parameter(torch.randn(1, 512, embed_dim))  # Max seq length: 512
        
        # Add small dropout to encoder layers for regularization
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=n_heads, batch_first=True, dropout=dropout)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
        self.fc_out = nn.Linear(embed_dim, vocab_size)

    def forward(self, x, src_key_padding_mask=None):
        # x shape: [batch, seq_len]
        seq_len = x.size(1)
        x = self.embedding(x) + self.pos_encoder[:, :seq_len, :]
        x = self.transformer(x, src_key_padding_mask=src_key_padding_mask)
        
        # Output logits for all positions
        # Shape: [batch, seq_len, vocab_size]
        return self.fc_out(x)

# %%
# ==========================================
# 4. EXECUTION (Load -> Train -> Save)
# ==========================================

# Custom collate function to handle variable-length sequences
def collate_fn(batch):
    """
    Pad sequences to max length in batch and return masks and a targets tensor
    Targets tensor uses -100 for positions to ignore (padding and non-masked positions)
    """
    inputs, mask_positions_list, target_ids_list = zip(*batch)
    
    # Pad input sequences
    max_len = max(seq.size(0) for seq in inputs)
    
    padded_inputs = []
    src_key_padding_masks = []  # False for real tokens, True for padding
    target_batch = []  # will be [batch, max_len] with -100 for ignored positions
    
    for inp, mask_pos, tgt_ids in zip(inputs, mask_positions_list, target_ids_list):
        if inp.size(0) < max_len:
            padded = torch.cat([inp, torch.full((max_len - inp.size(0),), tokenizer.pad_token_id, dtype=torch.long)])
            mask = torch.cat([torch.zeros(inp.size(0)), torch.ones(max_len - inp.size(0))])
        else:
            padded = inp
            mask = torch.zeros(max_len)
        
        padded_inputs.append(padded)
        src_key_padding_masks.append(mask.bool())
        
        # Build target row filled with -100 (ignore index)
        tgt_row = torch.full((max_len,), -100, dtype=torch.long)
        # mask_pos is a tensor of positions (relative to original seq length)
        for i, pos in enumerate(mask_pos.tolist()):
            if pos < max_len:
                tgt_row[pos] = tgt_ids[i]
        target_batch.append(tgt_row)
    
    inputs_batch = torch.stack(padded_inputs)
    src_key_padding_masks_batch = torch.stack(src_key_padding_masks)
    target_batch = torch.stack(target_batch)
    
    return inputs_batch, src_key_padding_masks_batch, target_batch

# A. Setup
print("1. Tokenizing data...")
tokenizer = BrahmiTokenizer(FILENAME)
dataset = BrahmiMaskedDataset(FILENAME, tokenizer)
from torch.utils.data import DataLoader, Sampler

# Sort dataset by sequence length to minimize padding waste
lengths = [item['input'].size(0) for item in dataset.data]
sorted_indices = sorted(range(len(lengths)), key=lambda i: lengths[i])

class SortedBatchSampler(Sampler):
    def __init__(self, sorted_indices, batch_size, shuffle_batches=True):
        self.batches = [
            sorted_indices[i:i+batch_size] 
            for i in range(0, len(sorted_indices), batch_size)
        ]
        self.shuffle_batches = shuffle_batches

    def __iter__(self):
        if self.shuffle_batches:
            random.shuffle(self.batches)
        for batch in self.batches:
            yield batch

    def __len__(self):
        return len(self.batches)

sampler = SortedBatchSampler(sorted_indices, BATCH_SIZE, shuffle_batches=True)
dataloader = DataLoader(dataset, batch_sampler=sampler, collate_fn=collate_fn)
# dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
print(f"   Vocab Size: {tokenizer.vocab_size}")
print(f"   Total Training Examples: {len(dataset)}")
# Out:
# 1. Tokenizing data...
#    Vocab Size: 134
#    Total Training Examples: 51534

# %%
# Re-run after changes to confirm valid fraction improved
inputs, src_key_padding_mask, targets = next(iter(dataloader))
valid_frac = (targets != -100).float().mean().item()
padding_frac = (inputs == tokenizer.pad_token_id).float().mean().item()
print(f"Valid target fraction: {valid_frac:.3f}  (want > 0.10)")
print(f"Padding fraction: {padding_frac:.3f}     (want < 0.30)")
# Out:
# Valid target fraction: 0.050  (want > 0.10)
# Padding fraction: 0.000     (want < 0.30)

# %%
# B. Initialize Model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(torch.cuda.is_available())
model = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS, tokenizer.pad_token_id, dropout=0.1).to(device)
optimizer = optim.Adam(model.parameters(), lr=LR)
# Use ignore_index=-100 because targets use -100 for non-masked positions
# reduction='none' lets us normalize each sample by how many masks it has
criterion = nn.CrossEntropyLoss(ignore_index=-100, reduction='none', label_smoothing=0.05)
# Scheduler to reduce LR on plateau of validation/train loss
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)
# Out:
# True

# %%
# C. Training Loop
print(f"2. Starting Training on {device}...")
model.train()

for epoch in range(EPOCHS):
    total_loss = 0.0
    batch_count = 0

    # --- Sanity check accumulators ---
    sanity_correct = 0
    sanity_total = 0

    for inputs, src_key_padding_mask, targets in dataloader:
        inputs = inputs.to(device)
        src_key_padding_mask = src_key_padding_mask.to(device)
        targets = targets.to(device)  # shape: [batch, seq_len]

        optimizer.zero_grad()

        # Get model predictions for all positions
        outputs = model(inputs, src_key_padding_mask=src_key_padding_mask)  # [batch, seq_len, vocab_size]

        # Normalize each sample by its number of masked positions so 1-mask and 4-mask
        # examples contribute comparably during training.
        vocab_size = outputs.size(-1)
        per_token_loss = criterion(outputs.reshape(-1, vocab_size), targets.reshape(-1))
        per_token_loss = per_token_loss.view(targets.size(0), -1)
        valid_mask = (targets != -100).float()
        masked_counts = valid_mask.sum(dim=1).clamp_min(1.0)
        sample_loss = (per_token_loss * valid_mask).sum(dim=1) / masked_counts
        loss = sample_loss.mean()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        batch_count += 1

        # --- Sanity check: top-1 accuracy on masked positions ---
        with torch.no_grad():
            predicted_ids = outputs.argmax(dim=-1)       # [batch, seq_len]
            mask = (targets != -100)                      # True only at masked positions
            sanity_correct += (predicted_ids[mask] == targets[mask]).sum().item()
            sanity_total   += mask.sum().item()

    avg_loss = total_loss / (batch_count if batch_count > 0 else 1)
    train_acc = (sanity_correct / sanity_total * 100) if sanity_total > 0 else 0.0

    print(f"   Epoch {epoch+1}/{EPOCHS} | Loss: {avg_loss:.4f} | Train Acc: {train_acc:.1f}%"
          f"  {'⚠️  stuck near random' if train_acc < 5.0 and epoch >= 2 else ''}")

    scheduler.step(avg_loss)
# Out:
# 2. Starting Training on cuda...
#    Epoch 1/20 | Loss: 3.7269 | Train Acc: 17.3%
#    Epoch 2/20 | Loss: 3.2739 | Train Acc: 28.0%
#    Epoch 3/20 | Loss: 3.0418 | Train Acc: 32.9%
#    Epoch 4/20 | Loss: 2.8058 | Train Acc: 38.3%
#    Epoch 5/20 | Loss: 2.4651 | Train Acc: 46.6%
#    Epoch 6/20 | Loss: 2.0689 | Train Acc: 56.2%
#    Epoch 7/20 | Loss: 1.7529 | Train Acc: 64.3%
#    Epoch 8/20 | Loss: 1.5316 | Train Acc: 70.0%
#    Epoch 9/20 | Loss: 1.3778 | Train Acc: 74.1%
#    Epoch 10/20 | Loss: 1.2571 | Train Acc: 77.1%
#    Epoch 11/20 | Loss: 1.1718 | Train Acc: 79.4%
#    Epoch 12/20 | Loss: 1.1010 | Train Acc: 81.4%
#    Epoch 13/20 | Loss: 1.0460 | Train Acc: 82.9%
#    Epoch 14/20 | Loss: 1.0022 | Train Acc: 84.1%
#    Epoch 15/20 | Loss: 0.9664 | Train Acc: 85.1%
#    Epoch 16/20 | Loss: 0.9327 | Train Acc: 86.1%
#    Epoch 17/20 | Loss: 0.9069 | Train Acc: 86.8%
#    Epoch 18/20 | Loss: 0.8829 | Train Acc: 87.6%
#    Epoch 19/20 | Loss: 0.8618 | Train Acc: 88.1%
# ...

# %%
# D. Save the model
torch.save(model.state_dict(), MODEL_PATH)
print("3. Model saved as 'brahmi_model.pth'")
# Out:
# 3. Model saved as 'brahmi_model.pth'

# %%
# ==========================================
# 5. TEST IT (Inference)
# ==========================================
# Ensure the model is loaded with the state dictionary

import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pad_token_id = getattr(tokenizer, 'pad_token_id', 0)
model_instance = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS, pad_token_id).to(device)
model_instance.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model_instance.eval()

def predict(text_with_underscores):
    """
    Predict 1-4 missing characters marked with '_' in the input text.
    Returns a dict mapping masked positions to predicted characters.
    """
    # 1. Split text into graphemes
    graphemes = tokenizer.get_graphemes(text_with_underscores)
    
    # 2. Find all underscore positions
    mask_positions = []
    for i, g in enumerate(graphemes):
        if g == '_':
            mask_positions.append(i)
    
    if not mask_positions:
        return "Error: No '_' found in input"
    
    if len(mask_positions) > 4:
        return "Error: More than 4 missing characters. Max is 4."
    
    # 3. Encode the sequence with underscores mapped to <mask>
    encoded = tokenizer.encode(graphemes)
    input_tensor = torch.tensor([encoded]).to(device)
    
    # 4. Get predictions for all positions
    with torch.no_grad():
        logits = model_instance(input_tensor)  # [1, seq_len, vocab_size]
        
    # 5. Collect predictions for masked positions
    predictions = {}
    for pos in mask_positions:
        predicted_id = torch.argmax(logits[0, pos, :]).item()
        predicted_char = tokenizer.idx2char.get(predicted_id, '')
        predictions[pos] = predicted_char
    
    return predictions

# %%
print("\n--- TEST (Multiple Masks) ---")
# Test with 1 missing character
test_sentence_1 = "𑀫𑀗𑁆𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂𑀝𑀼𑀫𑀸𑀭_𑀘𑁂𑀬𑁆𑀢𑀢𑀸"
print(f"\n1 missing char - Input: {test_sentence_1}")
print(f"Predictions: {predict(test_sentence_1)}")

# Test with 2 missing characters
test_sentence_2 = "𑀫𑀗𑁆_𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂_𑀼𑀫𑀸𑀭𑀸"
print(f"\n2 missing chars - Input: {test_sentence_2}")
print(f"Predictions: {predict(test_sentence_2)}")

# Test with 3 missing characters
test_sentence_3 = "𑀫_𑁆𑀓𑁃𑀬_𑀭𑁆𑀦𑁂𑀝_𑀫𑀸𑀭𑀸"
print(f"\n3 missing chars - Input: {test_sentence_3}")
print(f"Predictions: {predict(test_sentence_3)}")

# Test with 4 missing characters
test_sentence_4 = "_𑀗𑁆𑀓_𑀬𑀽𑀭_𑀦𑁂𑀝𑀼_𑀸𑀭𑀸"
print(f"\n4 missing chars - Input: {test_sentence_4}")
print(f"Predictions: {predict(test_sentence_4)}")
# Out:
# --- TEST (Multiple Masks) ---
#
# 1 missing char - Input: 𑀫𑀗𑁆𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂𑀝𑀼𑀫𑀸𑀭_𑀘𑁂𑀬𑁆𑀢𑀢𑀸
# Predictions: {9: '𑀦𑁆'}
#
# 2 missing chars - Input: 𑀫𑀗𑁆_𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂_𑀼𑀫𑀸𑀭𑀸
# Predictions: {2: '𑀢'}
#
# 3 missing chars - Input: 𑀫_𑁆𑀓𑁃𑀬_𑀭𑁆𑀦𑁂𑀝_𑀫𑀸𑀭𑀸
# Predictions: {4: '𑀢𑀼', 8: '𑀬'}
#
# 4 missing chars - Input: _𑀗𑁆𑀓_𑀬𑀽𑀭_𑀦𑁂𑀝𑀼_𑀸𑀭𑀸
# Predictions: {0: '𑀫𑀸', 3: '𑀓𑀼', 6: '𑀓𑀼'}

# %%
def calculate_accuracy(file_path, model, tokenizer):
    """
    Calculate accuracy for models that predict 1-4 missing characters.
    Returns overall accuracy and per-mask accuracy.
    """
    model.eval()
    total_predictions = 0
    correct_predictions = 0
    per_mask_stats = {i: {'correct': 0, 'total': 0} for i in range(1, 5)}
    
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    for line in lines:
        line = line.strip()
        if not line:
            continue
        
        graphemes = tokenizer.get_graphemes(line)
        
        # Test with variable numbers of masks (1-4)
        for num_masks in range(1, min(5, len(graphemes))):  # Test with 1-4 masks
            # Randomly select positions to mask
            mask_positions = sorted(random.sample(range(len(graphemes)), num_masks))
            
            test_graphemes = graphemes.copy()
            actual_chars = [graphemes[pos] for pos in mask_positions]
            
            for pos in mask_positions:
                test_graphemes[pos] = '_'
            test_sentence = "".join(test_graphemes)
            
            predictions = predict(test_sentence)
            
            if isinstance(predictions, dict):
                for i, pos in enumerate(mask_positions):
                    actual_char = actual_chars[i]
                    predicted_char = predictions.get(pos, '')
                    
                    if predicted_char == actual_char:
                        correct_predictions += 1
                        per_mask_stats[num_masks]['correct'] += 1
                    
                    total_predictions += 1
                    per_mask_stats[num_masks]['total'] += 1
    
    overall_accuracy = (correct_predictions / total_predictions * 100) if total_predictions > 0 else 0
    
    print(f"\nOverall Accuracy: {overall_accuracy:.2f}% ({correct_predictions}/{total_predictions})")
    print("\nAccuracy by number of missing characters:")
    for num_masks in range(1, 5):
        if per_mask_stats[num_masks]['total'] > 0:
            acc = per_mask_stats[num_masks]['correct'] / per_mask_stats[num_masks]['total'] * 100
            print(f"  {num_masks} mask(s): {acc:.2f}% ({per_mask_stats[num_masks]['correct']}/{per_mask_stats[num_masks]['total']})")
    
    return overall_accuracy

accuracy = calculate_accuracy(FILENAME, model_instance, tokenizer)
# Out:
# Overall Accuracy: 94.30% (9430/10000)
#
# Accuracy by number of missing characters:
#   1 mask(s): 97.10% (971/1000)
#   2 mask(s): 95.90% (1918/2000)
#   3 mask(s): 93.13% (2794/3000)
#   4 mask(s): 93.67% (3747/4000)

# %%
from sklearn.metrics import precision_recall_fscore_support, classification_report

def evaluate_model(file_path, model, tokenizer):
    """
    Comprehensive evaluation for multiple mask prediction.
    """
    model.eval()
    all_predictions = []
    all_actuals = []
    num_masks_distribution = []
    
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    sample_count = 0
    for line in lines:
        line = line.strip()
        if not line:
            continue
        
        graphemes = tokenizer.get_graphemes(line)
        
        # Test with variable numbers of masks
        for num_masks in range(1, min(5, len(graphemes))):
            if sample_count >= 1000:  # Limit samples for efficiency
                break
            
            # Randomly select positions to mask
            mask_positions = sorted(random.sample(range(len(graphemes)), num_masks))
            
            test_graphemes = graphemes.copy()
            actual_chars = [graphemes[pos] for pos in mask_positions]
            
            for pos in mask_positions:
                test_graphemes[pos] = '_'
            test_sentence = "".join(test_graphemes)
            
            predictions = predict(test_sentence)
            
            if isinstance(predictions, dict):
                for i, pos in enumerate(mask_positions):
                    actual_char = actual_chars[i]
                    predicted_char = predictions.get(pos, '')
                    
                    all_predictions.append(predicted_char)
                    all_actuals.append(actual_char)
                    num_masks_distribution.append(num_masks)
                    sample_count += 1
    
    # Calculate metrics
    if all_actuals:
        precision, recall, f1, _ = precision_recall_fscore_support(
            all_actuals, all_predictions, average='weighted', zero_division=0
        )
        print(f"\nWeighted Metrics:")
        print(f"  Precision: {precision:.4f}")
        print(f"  Recall: {recall:.4f}")
        print(f"  F1-Score: {f1:.4f}")
        print(f"\nDetailed Classification Report:")
        print(classification_report(all_actuals, all_predictions, zero_division=0))
    
    return all_actuals, all_predictions, num_masks_distribution

ac, pr, mask_dist = evaluate_model(FILENAME, model_instance, tokenizer)
# Out:
# Weighted Metrics:
#   Precision: 0.9507
#   Recall: 0.9480
#   F1-Score: 0.9463
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            𑀅       0.94      0.94      0.94        17
#            𑀆       1.00      1.00      1.00         1
#            𑀇       0.75      1.00      0.86         3
#            𑀈       1.00      1.00      1.00        10
#            𑀉       1.00      0.75      0.86         4
#            𑀊       1.00      0.75      0.86         4
#            𑀏       1.00      0.86      0.92         7
#            𑀑       1.00      0.75      0.86         4
#            𑀓       0.93      0.97      0.95        38
#           𑀓𑀸       0.86      0.75      0.80         8
#           𑀓𑀺       0.83      1.00      0.91        10
#           𑀓𑀼       0.96      0.96      0.96        24
#           𑀓𑁂       0.00      0.00      0.00         1
#           𑀓𑁃       1.00      0.92      0.96        12
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(ac, pr)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=False, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
import json
import regex as re

# 1. Read the SAME training file used in training
with open(FILENAME, 'r', encoding='utf-8') as f:
    text = f.read()

# 2. Extract unique graphemes and sort them EXACTLY like training
graphemes = re.findall(r'\X', text)
unique_chars = sorted(list(set(graphemes)))

# 3. Build the map (must match training tokenizer)
vocab = {'<pad>': 0, '<mask>': 1, '<unk>': 2}
for i, char in enumerate(unique_chars):
    vocab[char] = i + 3

# 4. Save to JSON for inference
with open('vocab.json', 'w', encoding='utf-8') as f:
    json.dump(vocab, f, ensure_ascii=False, indent=2)

print(f"Vocabulary saved from {FILENAME}")
print(f"Total unique graphemes: {len(unique_chars)}")
# Out:
# Vocabulary saved from data/strings.txt
# Total unique graphemes: 131

# %%
import torch
import torch.nn as nn
import regex as re
import json

# --- Config ---
MODEL_PATH = MODEL_PATH  # Use the trained model from training
VOCAB_PATH = 'vocab.json'
device ='cpu'# torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# --- Tokenizer (matches training) ---
class BrahmiTokenizer:
    def __init__(self, json_path):
        with open(json_path, 'r', encoding='utf-8') as f:
            self.char2idx = json.load(f)
        self.idx2char = {v: k for k, v in self.char2idx.items()}
        self.vocab_size = len(self.char2idx)
        self.pad_token_id = self.char2idx.get('<pad>', 0)
        self.mask_token_id = self.char2idx.get('<mask>', 1)
        self.unk_token_id = self.char2idx.get('<unk>', 2)

    def get_graphemes(self, text):
        return re.findall(r'\X', text)

    def encode(self, text_list):
        encoded = []
        for g in text_list:
            if g == '_':
                encoded.append(self.mask_token_id)
            else:
                encoded.append(self.char2idx.get(g, self.unk_token_id))
        return encoded

# --- Model (matches training architecture) ---
class CharTransformer(nn.Module):
    def __init__(self, vocab_size, embed_dim, n_heads, n_layers, pad_token_id=0, dropout=0.1):
        super(CharTransformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_token_id)
        self.pos_encoder = nn.Parameter(torch.randn(1, 512, embed_dim))
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=n_heads, batch_first=True, dropout=dropout)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
        self.fc_out = nn.Linear(embed_dim, vocab_size)

    def forward(self, x, src_key_padding_mask=None):
        seq_len = x.size(1)
        x = self.embedding(x) + self.pos_encoder[:, :seq_len, :]
        x = self.transformer(x, src_key_padding_mask=src_key_padding_mask)
        return self.fc_out(x)

# --- Load ---
print("Loading tokenizer and model...")
tokenizer = BrahmiTokenizer(VOCAB_PATH)
model = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS, tokenizer.pad_token_id, dropout=0.1).to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()
print(f"Model loaded from {MODEL_PATH}")

# --- Inference: Handle 1-4 missing characters ---
def predict(text_with_underscores):
    """
    Predict 1-4 missing characters marked with '_' in input.
    Returns dict mapping positions to predicted characters.
    """
    graphemes = tokenizer.get_graphemes(text_with_underscores)
    
    # Find mask positions
    mask_positions = [i for i, g in enumerate(graphemes) if g == '_']
    if not mask_positions:
        return "Error: No '_' found"
    if len(mask_positions) > 4:
        return "Error: More than 4 masks"
    
    # Encode sequence (underscores become mask token)
    encoded = tokenizer.encode(graphemes)
    input_tensor = torch.tensor([encoded]).to(device)
    
    # Get predictions for all positions
    with torch.no_grad():
        logits = model(input_tensor)  # [1, seq_len, vocab_size]
    
    # Collect predictions at masked positions
    predictions = {}
    for pos in mask_positions:
        pred_id = torch.argmax(logits[0, pos, :]).item()
        predictions[pos] = tokenizer.idx2char.get(pred_id, '')
    
    return predictions

# --- Test ---
print("\n--- Inference Test (1-4 masks) ---")
test_1 = "𑀫𑀼𑀘𑀺𑀭𑀺𑀅𑀢𑀦𑁆𑀘𑁂𑀬𑁆𑀢𑀧𑀴𑁆𑀴𑀺𑁇𑀧𑁅𑀢𑁆𑀢𑀢𑀼𑀭𑀯𑀺𑀬𑀭𑁆𑀢𑀯𑀫𑁆𑀘𑁂𑀬𑁆𑀬𑀅𑀫𑀡𑀧𑁆𑀧𑀸𑀴𑀺𑁇"
# test_2 = "𑀫𑀗𑁆_𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂_𑀼𑀫𑀸𑀭𑀸"
# test_3 = "𑀫_𑁆𑀓𑁃𑀬_𑀭𑁆𑀦𑁂𑀝_𑀫𑀸𑀭𑀸"
# test_4 = "_𑀗𑁆𑀓_𑀬𑀽𑀭_𑀦𑁂𑀝𑀼_𑀸𑀭𑀸"

print(f"1 mask: {predict(test_1)}")
# print(f"2 masks: {predict(test_2)}")
# print(f"3 masks: {predict(test_3)}")
# print(f"4 masks: {predict(test_4)}")
# Out:
# Loading tokenizer and model...
# Model loaded from models/new_brahmi_model5.pth
#
# --- Inference Test (1-4 masks) ---
# 1 mask: Error: No '_' found
