# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np

# --- Configuration ---
CONTEXT_SIZE = 5  # 5 chars before, 5 chars after
WINDOW_SIZE = (CONTEXT_SIZE * 2) + 1  # Total input length = 11
BATCH_SIZE = 32
EMBED_DIM = 64
N_HEADS = 4
N_LAYERS = 2
LR = 0.001
EPOCHS = 50

# --- 1. Data Preparation ---
class CharTokenizer:
    def __init__(self, text):
        # Create a set of unique characters + special tokens
        chars = sorted(list(set(text)))
        self.char2idx = {c: i+2 for i, c in enumerate(chars)}
        
        # Reserve 0 for Padding, 1 for Mask
        self.char2idx['<pad>'] = 0
        self.char2idx['<mask>'] = 1
        
        self.idx2char = {i: c for c, i in self.char2idx.items()}
        self.vocab_size = len(self.char2idx)
        self.mask_token_id = self.char2idx['<mask>']
        self.pad_token_id = self.char2idx['<pad>']

    def encode(self, s):
        return [self.char2idx.get(c, 0) for c in s]

    def decode(self, indices):
        return "".join([self.idx2char.get(idx, '') for idx in indices])

class MaskedCharDataset(Dataset):
    def __init__(self, text, tokenizer):
        self.tokenizer = tokenizer
        self.data = []
        
        # Create sliding windows over the text
        # We iterate through the text and pick 'i' as the target to be masked
        encoded_text = tokenizer.encode(text)
        
        for i in range(len(encoded_text)):
            # Define window boundaries
            start = i - CONTEXT_SIZE
            end = i + CONTEXT_SIZE + 1
            
            # Extract window with padding if near edges
            src_window = []
            
            # Padding for left side
            if start < 0:
                src_window.extend([tokenizer.pad_token_id] * abs(start))
                src_window.extend(encoded_text[0:i])
            else:
                src_window.extend(encoded_text[start:i])
                
            # The Mask itself
            src_window.append(tokenizer.mask_token_id)
            
            # Padding for right side
            if end > len(encoded_text):
                src_window.extend(encoded_text[i+1:])
                src_window.extend([tokenizer.pad_token_id] * (end - len(encoded_text)))
            else:
                src_window.extend(encoded_text[i+1:end])
                
            target_char = encoded_text[i]
            
            self.data.append((torch.tensor(src_window), torch.tensor(target_char)))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# --- 2. Model Architecture (Transformer Encoder) ---
class CharTransformer(nn.Module):
    def __init__(self, vocab_size, embed_dim, n_heads, n_layers):
        super(CharTransformer, self).__init__()
        
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.pos_encoder = nn.Parameter(torch.randn(1, WINDOW_SIZE, embed_dim))
        
        encoder_layers = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=n_heads, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers=n_layers)
        
        self.fc_out = nn.Linear(embed_dim, vocab_size)

    def forward(self, x):
        # x shape: [batch_size, window_size]
        
        # 1. Embed and add position info
        x = self.embedding(x) + self.pos_encoder
        
        # 2. Pass through Transformer
        # We don't need a mask here because the Transformer Encoder looks at everything
        x = self.transformer_encoder(x)
        
        # 3. We only care about the prediction at the MASK position
        # The mask is always at the center index: CONTEXT_SIZE (e.g., index 5)
        mask_pos_output = x[:, CONTEXT_SIZE, :]
        
        output = self.fc_out(mask_pos_output)
        return output

# --- 3. Training & Inference ---

# Dummy Data (Brahmi text simulation or English for testing)
# You should load your JSON text here.
raw_text = "hello world this is a test string for the transformer model to predict missing chars" * 10

# Initialize
tokenizer = CharTokenizer(raw_text)
dataset = MaskedCharDataset(raw_text, tokenizer)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

model = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS)
optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

# Training Loop
print("Starting training...")
model.train()
for epoch in range(EPOCHS):
    total_loss = 0
    for src, tgt in dataloader:
        optimizer.zero_grad()
        output = model(src)
        loss = criterion(output, tgt)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    if (epoch+1) % 10 == 0:
        print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataloader):.4f}")

# Inference Function
def predict_missing(text_segment, model, tokenizer):
    model.eval()
    # Ensure segment is exactly 11 chars with '_' in middle
    # For flexibility, we just find the '_' and take 5 chars around it
    if '_' not in text_segment:
        return "No mask found"
    
    mask_idx = text_segment.find('_')
    
    # Pad input manually if needed (simplified for demo)
    # Ideally, reuse the logic from Dataset class
    left_context = text_segment[max(0, mask_idx-5):mask_idx]
    right_context = text_segment[mask_idx+1:mask_idx+6]
    
    # Pad with <pad> if contexts are short
    left_ids = [tokenizer.pad_token_id] * (5 - len(left_context)) + tokenizer.encode(left_context)
    right_ids = tokenizer.encode(right_context) + [tokenizer.pad_token_id] * (5 - len(right_context))
    
    input_ids = left_ids + [tokenizer.mask_token_id] + right_ids
    input_tensor = torch.tensor([input_ids])
    
    with torch.no_grad():
        output = model(input_tensor)
        predicted_idx = torch.argmax(output, dim=1).item()
        
    return tokenizer.decode([predicted_idx])

# --- Test ---
test_str = "hello w_rld" # 'o' is missing
print(f"\nInput: {test_str}")
prediction = predict_missing(test_str, model, tokenizer)
print(f"Predicted: {prediction}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import regex as re

# ==========================================
# 1. CONFIGURATION
# ==========================================
FILENAME = 'data/strings.txt'  # REPLACE with your actual file name
CONTEXT_SIZE = 5              # 5 chars before, 5 chars after
WINDOW_SIZE = (CONTEXT_SIZE * 2) + 1
BATCH_SIZE = 32
EMBED_DIM = 64
N_HEADS = 4
N_LAYERS = 2
EPOCHS = 20
LR = 0.001

# %%
# ==========================================
# 2. DATA PREPARATION (Tokenizer & Dataset)
# ==========================================
class BrahmiTokenizer:
    def __init__(self, file_path):
        self.pad_token = '<pad>'
        self.mask_token = '<mask>'
        self.unk_token = '<unk>'
        
        # Read file to find all unique graphemes
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
        graphemes = re.findall(r'\X', text)
        unique_chars = sorted(list(set(graphemes)))
        
        # Build maps
        self.char2idx = {self.pad_token: 0, self.mask_token: 1, self.unk_token: 2}
        for i, char in enumerate(unique_chars):
            self.char2idx[char] = i + 3
        self.idx2char = {i: c for c, i in self.char2idx.items()}
        self.vocab_size = len(self.char2idx)

    def get_graphemes(self, text):
        return re.findall(r'\X', text)

    def encode(self, text_list):
        return [self.char2idx.get(g, self.char2idx[self.unk_token]) for g in text_list]

    def decode(self, indices):
        return "".join([self.idx2char.get(idx, '') for idx in indices])

class BrahmiMaskedDataset(Dataset):
    def __init__(self, file_path, tokenizer):
        self.data = []
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            
        for line in lines:
            line = line.strip()
            if not line: continue
            
            graphemes = tokenizer.get_graphemes(line)
            encoded = tokenizer.encode(graphemes)
            
            for i in range(len(encoded)):
                # Create window with padding
                left_start = i - CONTEXT_SIZE
                right_end = i + CONTEXT_SIZE + 1
                
                # Handle Left Padding
                if left_start < 0:
                    left = [tokenizer.char2idx['<pad>']] * abs(left_start) + encoded[0:i]
                else:
                    left = encoded[left_start:i]
                
                # Handle Right Padding
                if right_end > len(encoded):
                    right_part = encoded[i+1:]
                    right = right_part + [tokenizer.char2idx['<pad>']] * (CONTEXT_SIZE - len(right_part))
                else:
                    right = encoded[i+1 : right_end]
                
                # The Input: Left + MASK + Right
                input_seq = left + [tokenizer.char2idx['<mask>']] + right
                target = encoded[i]
                
                self.data.append((torch.tensor(input_seq), torch.tensor(target)))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
import torch.nn as nn
# ==========================================
# 3. THE MODEL (Transformer)
# ==========================================
class CharTransformer(nn.Module):
    def __init__(self, vocab_size, embed_dim, n_heads, n_layers):
        super(CharTransformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        # Learnable position markers
        self.pos_encoder = nn.Parameter(torch.randn(1, WINDOW_SIZE, embed_dim))
        
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=n_heads, batch_first=True)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
        self.fc_out = nn.Linear(embed_dim, vocab_size)

    def forward(self, x):
        # x shape: [batch, 11]
        x = self.embedding(x) + self.pos_encoder
        x = self.transformer(x)
        
        # We only look at the middle token (index 5) for prediction
        middle_token_output = x[:, CONTEXT_SIZE, :] 
        return self.fc_out(middle_token_output)

# %%
# ==========================================
# 4. EXECUTION (Load -> Train -> Save)
# ==========================================

# A. Setup
print("1. Tokenizing data...")
tokenizer = BrahmiTokenizer(FILENAME)
dataset = BrahmiMaskedDataset(FILENAME, tokenizer)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
print(f"   Vocab Size: {tokenizer.vocab_size}")
print(f"   Total Training Examples: {len(dataset)}")
# Out:
# 1. Tokenizing data...
#    Vocab Size: 134
#    Total Training Examples: 51534

# %%
# B. Initialize Model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS).to(device)
optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

# %%
# C. Training Loop
print(f"2. Starting Training on {device}...")
model.train()

for epoch in range(EPOCHS):
    total_loss = 0
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        output = model(inputs) # Data fed here!
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    avg_loss = total_loss / len(dataloader)
    print(f"   Epoch {epoch+1}/{EPOCHS} | Loss: {avg_loss:.4f}")
# Out:
# 2. Starting Training on cpu...
#    Epoch 1/20 | Loss: 1.9100
#    Epoch 2/20 | Loss: 1.0049
#    Epoch 3/20 | Loss: 0.8017
#    Epoch 4/20 | Loss: 0.6753
#    Epoch 5/20 | Loss: 0.5975
#    Epoch 6/20 | Loss: 0.5374
#    Epoch 7/20 | Loss: 0.4984
#    Epoch 8/20 | Loss: 0.4604
#    Epoch 9/20 | Loss: 0.4368
#    Epoch 10/20 | Loss: 0.4079
#    Epoch 11/20 | Loss: 0.3914
#    Epoch 12/20 | Loss: 0.3683
#    Epoch 13/20 | Loss: 0.3547
#    Epoch 14/20 | Loss: 0.3409
#    Epoch 15/20 | Loss: 0.3351
#    Epoch 16/20 | Loss: 0.3143
#    Epoch 17/20 | Loss: 0.3118
#    Epoch 18/20 | Loss: 0.2999
#    Epoch 19/20 | Loss: 0.2927
#    Epoch 20/20 | Loss: 0.2900

# %%
# D. Save the model
torch.save(model.state_dict(), "brahmi_model.pth")
print("3. Model saved as 'brahmi_model.pth'")
# Out:
# 3. Model saved as 'brahmi_model.pth'

# %%
# ==========================================
# 5. TEST IT (Inference)
# ==========================================
# Ensure the model is loaded with the state dictionary

import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load("models/transformer.pth")
model_instance = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS).to(device)
model_instance.load_state_dict(model)
model_instance.eval()

def predict(text_with_underscore):
    # 1. Split text into graphemes (handling Brahmi chars)
    graphemes = tokenizer.get_graphemes(text_with_underscore)
    
    # 2. Find the underscore
    try:
        mask_index = graphemes.index('_')
    except ValueError:
        return "Error: No '_' found in input"

    # 3. Build context vectors manually
    # (This logic mirrors the Dataset logic strictly)
    left_part = graphemes[max(0, mask_index-CONTEXT_SIZE) : mask_index]
    right_part = graphemes[mask_index+1 : mask_index+1+CONTEXT_SIZE]
    
    left_ids = [tokenizer.char2idx['<pad>']] * (CONTEXT_SIZE - len(left_part)) + tokenizer.encode(left_part)
    right_ids = tokenizer.encode(right_part) + [tokenizer.char2idx['<pad>']] * (CONTEXT_SIZE - len(right_part))
    
    input_ids = left_ids + [tokenizer.char2idx['<mask>']] + right_ids
    input_tensor = torch.tensor([input_ids]).to(device)
    
    # 4. Predict
    with torch.no_grad():
        logits = model_instance(input_tensor)
        predicted_id = torch.argmax(logits, dim=1).item()
        
    return tokenizer.decode([predicted_id])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       8 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#       9 model = torch.load("models/transformer.pth")
# ---> 10 model_instance = CharTransformer(tokenizer.vocab_size, EMBED_DIM, N_HEADS, N_LAYERS).to(device)
#      11 model_instance.load_state_dict(model)
#      12 model_instance.eval()
#
# NameError: name 'tokenizer' is not defined

# %%
print("\n--- TEST ---")
# Replace with a real example from your file, putting '_' where the missing char is
# Example: If sentence is ABC, try A_C
test_sentence = "𑀫𑀗𑁆𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂𑀝𑀼𑀫𑀸𑀭𑀦𑁆𑀘𑁂𑀬𑁆𑀢𑀢𑀸𑀦𑀫𑁆𑁇𑀧𑀼𑀓𑀴𑀽_" # Example context, answer: 𑀭𑁆
print(f"Input: {test_sentence}")
print(f"Prediction: {predict(test_sentence)}")

# %%
# Function to calculate accuracy
def calculate_accuracy(file_path, model, tokenizer):
    model.eval()
    total_predictions = 0
    correct_predictions = 0
    
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    for line in lines:
        line = line.strip()
        if not line:
            continue
        
        graphemes = tokenizer.get_graphemes(line)
        for i in range(len(graphemes)):
            # Create a test sentence with '_' replacing the current character
            test_graphemes = graphemes[:]
            actual_char = graphemes[i]
            test_graphemes[i] = '_'
            test_sentence = "".join(test_graphemes)
            
            # Predict the missing character
            prediction = predict(test_sentence)
            
            # Compare prediction with the actual character
            if prediction == actual_char:
                correct_predictions += 1
            total_predictions += 1
    
    # Calculate accuracy
    accuracy = (correct_predictions / total_predictions) * 100
    return accuracy

# Calculate and print accuracy
accuracy = calculate_accuracy(FILENAME, model_instance, tokenizer)
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 97.30%

# %%
import json
import regex as re

# 1. Read the original training file
with open('data/transformer_data/strings.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# 2. Extract unique graphemes and sort them EXACTLY like training
unique_chars = sorted(list(set(re.findall(r'\X', text))))

# 3. Build the map
vocab = {'<pad>': 0, '<mask>': 1, '<unk>': 2}
for i, char in enumerate(unique_chars):
    vocab[char] = i + 3

# 4. Save to JSON
with open('vocab.json', 'w', encoding='utf-8') as f:
    json.dump(vocab, f, ensure_ascii=False, indent=2)

print("Success! You can now delete 'brahmi_data.txt' and use 'vocab.json'.")
# Out:
# Success! You can now delete 'brahmi_data.txt' and use 'vocab.json'.

# %%
import torch
import torch.nn as nn
import regex as re
import json

# --- Config ---
MODEL_PATH = 'models/transformer.pth'
VOCAB_PATH = 'vocab.json' # Loading from JSON now
CONTEXT_SIZE = 5
EMBED_DIM = 64
N_HEADS = 4
N_LAYERS = 2
WINDOW_SIZE = (CONTEXT_SIZE * 2) + 1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# --- Helper Class ---
class BrahmiTokenizer:
    def __init__(self, json_path):
        with open(json_path, 'r', encoding='utf-8') as f:
            self.char2idx = json.load(f)
        self.idx2char = {v: k for k, v in self.char2idx.items()}
        self.vocab_size = len(self.char2idx)
        self.unk_idx = self.char2idx.get('<unk>', 2)

    def get_graphemes(self, text):
        return re.findall(r'\X', text)

    def encode(self, list_of_graphemes):
        return [self.char2idx.get(x, self.unk_idx) for x in list_of_graphemes]

# --- Model ---
class CharTransformer(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, EMBED_DIM)
        self.pos_encoder = nn.Parameter(torch.randn(1, WINDOW_SIZE, EMBED_DIM))
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=EMBED_DIM, nhead=N_HEADS, batch_first=True), 
            num_layers=N_LAYERS
        )
        
        # CHANGE: Renamed 'fc' to 'fc_out' to match your saved model
        self.fc_out = nn.Linear(EMBED_DIM, vocab_size)

    def forward(self, x):
        x = self.embedding(x) + self.pos_encoder
        # CHANGE: Use 'self.fc_out' here too
        return self.fc_out(self.transformer(x)[:, CONTEXT_SIZE, :])

# --- Load ---
tokenizer = BrahmiTokenizer(VOCAB_PATH)
model = CharTransformer(tokenizer.vocab_size).to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()

# --- Run ---
def predict(char_str):
    g = tokenizer.get_graphemes(char_str)
    if '_' not in g: return "No mask"
    
    idx = g.index('_')
    left = g[max(0, idx - CONTEXT_SIZE) : idx]
    right = g[idx + 1 : idx + 1 + CONTEXT_SIZE]

    # Pad 0s manually
    ids = ([0]*(CONTEXT_SIZE-len(left))) + tokenizer.encode(left) + \
          [1] + \
          tokenizer.encode(right) + ([0]*(CONTEXT_SIZE-len(right)))

    with torch.no_grad():
        logits = model(torch.tensor([ids]).to(device))
        pred = torch.argmax(logits, dim=1).item()
        
    return tokenizer.idx2char.get(pred, '')

# Test
print(predict("𑀫𑀗𑁆𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂𑀝𑀼𑀫𑀸𑀭_𑀘𑁂𑀬𑁆𑀢𑀢𑀸𑀦𑀫𑁆𑁇𑀧𑀼𑀓𑀴𑀽𑀭𑁆𑀘𑀫𑀡𑀫𑀼𑀦𑀺𑀯𑀭𑁆𑀓𑁆𑀓𑀼𑀇𑀧𑁆𑀧𑀴𑁆𑀴𑀺𑀅𑀫𑀡𑀧𑁆𑀧𑀸𑀴𑀺𑁇𑀅𑀭𑀫𑁆𑀯𑁂𑀮𑁆𑀓𑁇"))
#  "𑀫𑀗𑁆𑀓𑁃𑀬𑀽𑀭𑁆𑀦𑁂𑀝𑀼𑀫𑀸𑀭𑀸"
#𑀭𑁇𑀘𑁂𑀬𑁆𑀢𑀢𑀸𑀦𑀫𑁆𑁇𑀧𑀼𑀓𑀴𑀽𑀭𑁆𑀭𑁆𑀘𑀫𑀡𑀫𑀼𑀦𑀺𑀯𑀭𑁆𑀓𑁆𑀓𑀼𑀇𑀧𑁆𑀧𑀴𑁆𑀴𑀺𑀅𑀫𑀡𑀧𑁆𑀧𑀸𑀴𑀺𑁇𑁇𑀅𑀭𑀫𑁆𑀯𑁂𑀮𑁆𑀓𑁇
# Out:
# 𑀦𑁆
